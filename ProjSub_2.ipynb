# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %config InlineBackend.figure_format = 'retina'
sns.set(style="ticks")
plt.rc('figure', figsize=(6, 3.7), dpi=100)
plt.rc('axes', labelpad=20, facecolor="#ffffff", 
       linewidth=0.4, grid=True, labelsize=10)
plt.rc('patch', linewidth=0)
plt.rc('xtick.major', width=0.2)
plt.rc('ytick.major', width=0.2)
plt.rc('grid', color='#EEEEEE', linewidth=0.25)
plt.rc('font', family='Arial', weight='400', size=10)
plt.rc('text', color='#282828')
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)
plt.rc('savefig', pad_inches=0.3, dpi=300)

# %%
mydata = pd.read_csv('HousePrices.csv')

# %%
# Configuring float numbers format
pd.options.display.float_format = '{:20.2f}'.format
mydata.head(n=5)
# Out:
#    Id  MSSubClass MSZoning          LotFrontage  LotArea Street Alley  \
# 0   1          60       RL                65.00     8450   Pave   NaN
# 1   2          20       RL                80.00     9600   Pave   NaN
# 2   3          60       RL                68.00    11250   Pave   NaN
# 3   4          70       RL                60.00     9550   Pave   NaN
# 4   5          60       RL                84.00    14260   Pave   NaN
#
#   LotShape LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature  \
# 0      Reg         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 1      Reg         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 2      IR1         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 3      IR1         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 4      IR1         Lvl    AllPub  ...        0    NaN   NaN         NaN
#
#   MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
mydata.head()
# Out:
#    Id  MSSubClass MSZoning          LotFrontage  LotArea Street Alley  \
# 0   1          60       RL                65.00     8450   Pave   NaN
# 1   2          20       RL                80.00     9600   Pave   NaN
# 2   3          60       RL                68.00    11250   Pave   NaN
# 3   4          70       RL                60.00     9550   Pave   NaN
# 4   5          60       RL                84.00    14260   Pave   NaN
#
#   LotShape LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature  \
# 0      Reg         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 1      Reg         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 2      IR1         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 3      IR1         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 4      IR1         Lvl    AllPub  ...        0    NaN   NaN         NaN
#
#   MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
mydata.tail()
# Out:
#         Id  MSSubClass MSZoning          LotFrontage  LotArea Street Alley  \
# 1455  1456          60       RL                62.00     7917   Pave   NaN
# 1456  1457          20       RL                85.00    13175   Pave   NaN
# 1457  1458          70       RL                66.00     9042   Pave   NaN
# 1458  1459          20       RL                68.00     9717   Pave   NaN
# 1459  1460          20       RL                75.00     9937   Pave   NaN
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature  \
# 1455      Reg         Lvl    AllPub  ...        0    NaN    NaN         NaN
# 1456      Reg         Lvl    AllPub  ...        0    NaN  MnPrv         NaN
# 1457      Reg         Lvl    AllPub  ...        0    NaN  GdPrv        Shed
# 1458      Reg         Lvl    AllPub  ...        0    NaN    NaN         NaN
# 1459      Reg         Lvl    AllPub  ...        0    NaN    NaN         NaN
#
# ...

# %%
mydata.shape
# Out:
# (1460, 81)

# %%
mydata.describe()
# Out:
#                         Id           MSSubClass          LotFrontage  \
# count              1460.00              1460.00              1201.00
# mean                730.50                56.90                70.05
# std                 421.61                42.30                24.28
# min                   1.00                20.00                21.00
# 25%                 365.75                20.00                59.00
# 50%                 730.50                50.00                69.00
# 75%                1095.25                70.00                80.00
# max                1460.00               190.00               313.00
#
#                    LotArea          OverallQual          OverallCond  \
# count              1460.00              1460.00              1460.00
# mean              10516.83                 6.10                 5.58
# std                9981.26                 1.38                 1.11
# ...

# %% [markdown]
# #### From the table above, we can see,
# #### The average lot area of the houses in our dataset is 10,147.92 ft2 with a standard deviation of 7,880.02 ft2.
# #### We can see also that the minimum lot area is 1,300 ft2 and the maximum lot area is 215,245 ft2 with a median of 9,436.5 ft2.
# #### We now will see statistical information about the non-numerical columns in our dataset

# %%
mydata.describe(include=[np.object]).transpose() \
    .drop("count", axis=1)
# Out:
#               unique      top  freq
# MSZoning           5       RL  1151
# Street             2     Pave  1454
# Alley              2     Grvl    50
# LotShape           4      Reg   925
# LandContour        4      Lvl  1311
# Utilities          2   AllPub  1459
# LotConfig          5   Inside  1052
# LandSlope          3      Gtl  1382
# Neighborhood      25    NAmes   225
# Condition1         9     Norm  1260
# Condition2         8     Norm  1445
# BldgType           5     1Fam  1220
# HouseStyle         8   1Story   726
# RoofStyle          6    Gable  1141
# RoofMatl           8  CompShg  1434
# Exterior1st       15  VinylSd   515
# Exterior2nd       16  VinylSd   504
# MasVnrType         4     None   864
# ExterQual          4       TA   906
# ExterCond          5       TA  1282
# Foundation         6    PConc   647
# BsmtQual           4       TA   649
# BsmtCond           4       TA  1311
# BsmtExposure       4       No   953
# BsmtFinType1       6      Unf   430
# ...

# %%
mydata.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %% [markdown]
# #### LotFrontage has 259 null values

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
mydata.nunique()
# Out:
# Id               1460
# MSSubClass         15
# MSZoning            5
# LotFrontage       110
# LotArea          1073
#                  ...
# MoSold             12
# YrSold              5
# SaleType            9
# SaleCondition       6
# SalePrice         663
# Length: 81, dtype: int64

# %%
# Getting the number of missing values in each column
num_missing = mydata.isna().sum()
# Excluding columns that contains 0 missing values
num_missing = num_missing[num_missing > 0]
# Getting the percentages of missing values
percent_missing = num_missing * 100 / mydata.shape[0]
# Concatenating the number and perecentage of missing values 
# into one dataframe and sorting it
pd.concat([num_missing, percent_missing], axis=1, 
          keys=['Missing Values', 'Percentage']).\
          sort_values(by="Missing Values", ascending=False)
# Out:
#               Missing Values           Percentage
# PoolQC                  1453                99.52
# MiscFeature             1406                96.30
# Alley                   1369                93.77
# Fence                   1179                80.75
# FireplaceQu              690                47.26
# LotFrontage              259                17.74
# GarageType                81                 5.55
# GarageYrBlt               81                 5.55
# GarageFinish              81                 5.55
# GarageQual                81                 5.55
# GarageCond                81                 5.55
# BsmtExposure              38                 2.60
# BsmtFinType2              38                 2.60
# BsmtFinType1              37                 2.53
# BsmtCond                  37                 2.53
# BsmtQual                  37                 2.53
# MasVnrArea                 8                 0.55
# MasVnrType                 8                 0.55
# ...

# %%
mydata["PoolArea"].value_counts()
# Out:
# 0      1453
# 480       1
# 512       1
# 519       1
# 555       1
# 576       1
# 648       1
# 738       1
# Name: PoolArea, dtype: int64

# %% [markdown]
# #### We can see that there are 2917 entries in Pool Area column that have a value of 0. This verfies our hypothesis that each house without a pool has a missing value in Pool QC column and a value of 0 in Pool Area column. So let's fill the missing values in Pool QC column with "No Pool":

# %%
mydata["PoolQC"].fillna("No Pool", inplace=True)

# %% [markdown]
# #### The percentage of missing values in Pool QC column is 96.38% which is very high also. Let's take a look at the values of Misc Val column:

# %%
mydata["MiscVal"].value_counts()
# Out:
# 0        1408
# 400        11
# 500         8
# 700         5
# 450         4
# 600         4
# 2000        4
# 480         2
# 1200        2
# 2500        1
# 350         1
# 560         1
# 54          1
# 620         1
# 8300        1
# 800         1
# 1150        1
# 15500       1
# 1300        1
# 1400        1
# 3500        1
# Name: MiscVal, dtype: int64

# %% [markdown]
# #### We can see that Misc Val column has 2827 entries with a value of 0. Misc Feature has 2824 missing values. Then, as with Pool QC, we can say that each house without a "miscellaneous feature" has a missing value in Misc Feature column and a value of 0 in Misc Val column. So let's fill the missing values in Misc Feature column with "No Feature"

# %%
mydata['MiscFeature'].fillna('No feature', inplace=True)

# %% [markdown]
# #### According to the dataset documentation, NA in Alley, Fence, and Fireplace Qu columns denotes that the house doesn't have an alley, fence, or fireplace. So we fill in the missing values in these columns with "No Alley", "No Fence", and "No Fireplace" accordingly:

# %%
mydata['Alley'].fillna('No Alley', inplace=True)
mydata['Fence'].fillna('No Fence', inplace=True)
mydata['FireplaceQu'].fillna('No Fireplace', inplace=True)

# %% [markdown]
# #### As we saw previously, Lot Frontage represents the linear feet of street connected to the house. So we assume that the missing values in this column indicates that the house is not connected to any street, and we fill in the missing values with 0:

# %%
mydata['LotFrontage'].fillna(0, inplace=True)

# %%
garage_columns = [col for col in mydata.columns if col.startswith("Garage")]
mydata[mydata['GarageCars'].isna()][garage_columns]
# Out:
# Empty DataFrame
# Columns: [GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond]
# Index: []

# %%
mydata[~pd.isna(mydata['GarageType']) & 
        pd.isna(mydata['GarageQual'])][garage_columns]
# Out:
# Empty DataFrame
# Columns: [GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond]
# Index: []

# %%
mydata['GarageCars'].fillna(0, inplace=True)
mydata['GarageArea'].fillna(0, inplace=True)

mydata.loc[~pd.isna(mydata['GarageType']) & 
            pd.isna(mydata['GarageQual']), "GarageType"] = "No Garage"

for col in ['GarageType', 'GarageFinish', 'GarageQual', 'GarageCond']:
    mydata[col].fillna('No Garage', inplace=True)
    
mydata['GarageYrBlt'].fillna(0, inplace=True)

# %%
bsmt_columns = [col for col in mydata.columns if "Bsmt" in col]
mydata[mydata['BsmtHalfBath'].isna()][bsmt_columns]
# Out:
# Empty DataFrame
# Columns: [BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, BsmtFullBath, BsmtHalfBath]
# Index: []

# %%
mydata[~pd.isna(mydata['BsmtCond']) & 
        pd.isna(mydata['BsmtExposure'])][bsmt_columns]
# Out:
#     BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  \
# 948       Gd       TA          NaN          Unf           0          Unf
#
#      BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  BsmtFullBath  BsmtHalfBath
# 948           0        936          936             0             0

# %%
mydata[~pd.isna(mydata['BsmtCond']) & 
        pd.isna(mydata['BsmtFinType2'])][bsmt_columns]
# Out:
#     BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  \
# 332       Gd       TA           No          GLQ        1124          NaN
#
#      BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  BsmtFullBath  BsmtHalfBath
# 332         479       1603         3206             1             0

# %%
for col in ["BsmtHalfBath", "BsmtFullBath", "TotalBsmtSF", 
            "BsmtUnfSF", "BsmtFinSF2", "BsmtFinSF1"]:
    mydata[col].fillna(0, inplace=True)

mydata.loc[~pd.isna(mydata['BsmtCond']) & 
            pd.isna(mydata['BsmtExposure']), "BsmtExposure"] = "No"
mydata.loc[~pd.isna(mydata['BsmtCond']) & 
            pd.isna(mydata['BsmtFinType2']), "BsmtFinType2"] = "Unf"

for col in ["BsmtExposure", "BsmtFinType2", 
            "BsmtFinType1", "BsmtQual", "BsmtCond"]:
    mydata[col].fillna("No Basement", inplace=True)

# %%
mydata['MasVnrArea'].fillna(0, inplace=True)
mydata['MasVnrType'].fillna("None", inplace=True)

# %%
mydata['Electrical'].fillna(mydata['Electrical'].mode()[0], inplace=True)

# %%
mydata.isna().values.sum()
# Out:
# 0

# %% [markdown]
# #### This means that our dataset is now complete; it doesn't contain any missing value anymore.

# %%
from matplotlib import pyplot as plt
import seaborn as sns

plt.scatter(x=mydata['GrLivArea'], y=mydata['SalePrice'], 
            color="orange", edgecolors="#000000", linewidths=0.5);
plt.xlabel("GrLivArea"); plt.ylabel("SalePrice");

# %%
outlirt_columns = ["GrLivArea"] + \
                  [col for col in mydata.columns if "Sale" in col]
mydata[mydata["GrLivArea"] > 4000][outlirt_columns]
# Out:
#       GrLivArea SaleType SaleCondition  SalePrice
# 523        4676      New       Partial     184750
# 691        4316       WD        Normal     755000
# 1182       4476       WD       Abnorml     745000
# 1298       5642      New       Partial     160000

# %%
mydata = mydata[mydata["GrLivArea"] < 4000]

# %%
plt.scatter(x=mydata['GrLivArea'], y=mydata['SalePrice'], 
            color="blue", edgecolors="#000000", linewidths=0.5);
plt.xlabel("GrLivArea"); plt.ylabel("SalePrice");

# %%
mydata.reset_index(drop=True, inplace=True)

# %%
mydata.drop(['Id'], axis=1, inplace=True)

# %% [markdown]
# ### Exploratory Data Analysis

# %%
sns.violinplot(x=mydata['SalePrice'], inner="quartile", color="#ffd343");

# %%
sns.boxplot(mydata['SalePrice'], whis=10, color="#36B37E");

# %%
sns.distplot(mydata['SalePrice'], kde=False, 
             color="#00B8D9", hist_kws={"alpha": 0.8});
plt.ylabel("Count");

# %%
fig, ax = plt.subplots(figsize=(12,9))
sns.heatmap(mydata.corr(), ax=ax);

# %%
sns.distplot(mydata['SalePrice'], kde=False, 
             color="#172B4D", hist_kws={"alpha": 0.8});
plt.ylabel("Count");

# %%
sns.distplot(mydata['OverallQual'], kde=False, 
             color="#172B4D", hist_kws={"alpha": 1});
plt.ylabel("Count");

# %%
plt.scatter(x=mydata['OverallQual'], y=mydata['SalePrice'], 
            color="blue", edgecolors="#000000", linewidths=0.5);
plt.xlabel("Overall Qual"); plt.ylabel("SalePrice");

# %%
sns.distplot(mydata['GrLivArea'], kde=False, 
             color="#172B4D", hist_kws={"alpha": 0.8});
plt.ylabel("Count");

# %%
plt.scatter(x=mydata['GrLivArea'], y=mydata['SalePrice'], 
            color="Blue", edgecolors="#000000", linewidths=0.5);
plt.xlabel("GrLivArea"); plt.ylabel("SalePrice");

# %%
fig, axes = plt.subplots(1, 4, figsize=(18,5))
fig.subplots_adjust(hspace=0.5, wspace=0.6)
for ax, v in zip(axes.flat, ["YearBuilt", "YearRemodAdd", 
                             "MasVnrArea", "TotalBsmtSF"]):
    sns.distplot(mydata[v], kde=False, color="#172B4D", 
                 hist_kws={"alpha": 0.8}, ax=ax)
    ax.set(ylabel="Count");

# %%
x_vars = ["YearBuilt", "YearRemodAdd", "MasVnrArea", "TotalBsmtSF"]
g = sns.PairGrid(mydata, y_vars=["SalePrice"], x_vars=x_vars);
g.map(plt.scatter, color="Blue", edgecolors="#000000", linewidths=0.5);

# %%
fig, axes = plt.subplots(1, 4, figsize=(18,5))
fig.subplots_adjust(hspace=0.5, wspace=0.6)
for ax, v in zip(axes.flat, ["1stFlrSF", "FullBath", 
                             "GarageCars", "GarageArea"]):
    sns.distplot(mydata[v], kde=False, color="#172B4D", 
                 hist_kws={"alpha": 0.8}, ax=ax);
    ax.set(ylabel="Count");

# %%
x_vars = ["1stFlrSF", "FullBath", "GarageCars", "GarageArea"]
g = sns.PairGrid(mydata, y_vars=["SalePrice"], x_vars=x_vars);
g.map(plt.scatter, color="Blue", edgecolors="#000000", linewidths=0.5);

# %%
sns.distplot(mydata['TotRmsAbvGrd'], kde=False, 
             color="#172B4D", hist_kws={"alpha": 0.8});
plt.ylabel("Count");

# %%
plt.rc("grid", linewidth=0.05)
fig, axes = plt.subplots(1, 2, figsize=(15,5))
fig.subplots_adjust(hspace=0.5, wspace=0.4)
h1 = axes[0].hist2d(mydata["GarageCars"], 
                    mydata["GarageArea"],
                    cmap="viridis");
axes[0].set(xlabel="GarageCars", ylabel="GarageArea")
plt.colorbar(h1[3], ax=axes[0]);
h2 = axes[1].hist2d(mydata["GrLivArea"], 
                    mydata["TotRmsAbvGrd"],
                    cmap="viridis");
axes[1].set(xlabel="GrLivArea", ylabel="TotRmsAbvGrd")
plt.colorbar(h1[3], ax=axes[1]);
plt.rc("grid", linewidth=0.25)

# %%
fig, axes = plt.subplots(1, 3, figsize=(16,5))
fig.subplots_adjust(hspace=0.5, wspace=0.6)
for ax, v in zip(axes.flat, ["BsmtUnfSF", "BsmtFinSF1", "BsmtFullBath"]):
    sns.distplot(mydata[v], kde=False, color="#172B4D", 
                 hist_kws={"alpha": 0.8}, ax=ax);
    ax.set(ylabel="Count")

# %%
fig, axes = plt.subplots(1, 2, figsize=(15,5))
fig.subplots_adjust(hspace=0.5, wspace=0.4)
axes[0].scatter(mydata["BsmtUnfSF"], mydata["BsmtFinSF1"],
                color="Blue", edgecolors="#000000", linewidths=0.5);
axes[0].set(xlabel="BsmtUnfSF", ylabel="BsmtFinSF1");
axes[1].scatter(mydata["BsmtUnfSF"], mydata["BsmtFullBath"],
                color="Blue", edgecolors="#000000", linewidths=0.5);
axes[1].set(xlabel="BsmtUnfSF", ylabel="BsmtFullBath");

# %%
for f in ["OverallQual", "GrLivArea"]:
    mydata[f + "_p2"] = mydata[f] ** 2
    mydata[f + "_p3"] = mydata[f] ** 3
mydata["OverallQual_GrLivArea"] = \
    mydata["OverallQual"] * mydata["GrLivArea"]

# %%
mydata.drop(["GarageCars", "TotRmsAbvGrd"], axis=1, inplace=True)

# %%
print("Unique values in 'Bsmt Cond' column:")
print(mydata['BsmtCond'].unique().tolist())
# Out:
# Unique values in 'Bsmt Cond' column:
# ['TA', 'Gd', 'No Basement', 'Fa', 'Po']

# %%
mp = {'Ex':4,'Gd':3,'TA':2,'Fa':1,'Po':0}
mydata['ExterQual'] = mydata['ExterQual'].map(mp)
mydata['ExterCond'] = mydata['ExterCond'].map(mp)
mydata['HeatingQC'] = mydata['HeatingQC'].map(mp)
mydata['KitchenQual'] = mydata['KitchenQual'].map(mp)

mp = {'Ex':5,'Gd':4,'TA':3,'Fa':2,'Po':1,'No Basement':0}
mydata['BsmtQual'] = mydata['BsmtQual'].map(mp)
mydata['BsmtCond'] = mydata['BsmtCond'].map(mp)
mydata['BsmtExposure'] = mydata['BsmtExposure'].map(
    {'Gd':4,'Av':3,'Mn':2,'No':1,'No Basement':0})

mp = {'GLQ':6,'ALQ':5,'BLQ':4,'Rec':3,'LwQ':2,'Unf':1,'No Basement':0}
mydata['BsmtFinType1'] = mydata['BsmtFinType1'].map(mp)
mydata['BsmtFinType2'] = mydata['BsmtFinType2'].map(mp)

mydata['CentralAir'] = mydata['CentralAir'].map({'Y':1,'N':0})
mydata['Functional'] = mydata['Functional'].map(
    {'Typ':7,'Min1':6,'Min2':5,'Mod':4,'Maj1':3,
     'Maj2':2,'Sev':1,'Sal':0})
mydata['FireplaceQu'] = mydata['FireplaceQu'].map(
    {'Ex':5,'Gd':4,'TA':3,'Fa':2,'Po':1,'NoFireplace':0})
mydata['GarageFinish'] = mydata['GarageFinish'].map(
    {'Fin':3,'RFn':2,'Unf':1,'NoGarage':0})
mydata['GarageQual'] = mydata['GarageQual'].map(
    {'Ex':5,'Gd':4,'TA':3,'Fa':2,'Po':1,'NoGarage':0})
mydata['GarageCond'] = mydata['GarageCond'].map(
    {'Ex':5,'Gd':4,'TA':3,'Fa':2,'Po':1,'NoGarage':0})
mydata['PoolQC'] = mydata['PoolQC'].map(
    {'Ex':4,'Gd':3,'TA':2,'Fa':1,'NoPool':0})
mydata['Land lope'] = mydata['LandSlope'].map(
    {'Sev': 2, 'Mod': 1, 'Gtl': 0})
mydata['Fence'] = mydata['Fence'].map(
    {'GdPrv':4,'MnPrv':3,'GdWo':2,'MnWw':1,'NoFence':0})

# %%
mydata[['PavedDrive']].head()mydata[['SalePrice']].head()
# Out:
#   PavedDrive
# 0          Y
# 1          Y
# 2          Y
# 3          Y
# 4          Y

# %%
mydata = pd.get_dummies(mydata)

# %%
pavedDrive_oneHot = [c for c in mydata.columns if c.startswith("Paved")]
mydata[pavedDrive_oneHot].head()
# Out:
#    PavedDrive_N  PavedDrive_P  PavedDrive_Y
# 0             0             0             1
# 1             0             0             1
# 2             0             0             1
# 3             0             0             1
# 4             0             0             1

# %%
mydata[['SalePrice']].head()
# Out:
#    SalePrice
# 0     208500
# 1     181500
# 2     223500
# 3     140000
# 4     250000

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
# We need to fit the scaler to our data before transformation
mydata.loc[:, mydata.columns != 'SalePrice'] = scaler.fit_transform(
    mydata.loc[:, mydata.columns != 'SalePrice'])

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import  RandomizedSearchCV
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    mydata.drop('SalePrice', axis=1), mydata[['SalePrice']], 
    test_size=0.25, random_state=3)

# %%
model = DecisionTreeRegressor(max_depth=14, min_samples_split=5, max_features=20)

# %%
parameter_space = {
    "max_depth": [7, 15],
    "min_samples_split": [5, 10],
    "max_features": [30, 45]
}

clf = GridSearchCV(DecisionTreeRegressor(), parameter_space, cv=4, 
                   scoring="neg_mean_absolute_error")

clf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-146-aeb339ae94db> in <module>
#       8                    scoring="neg_mean_absolute_error")
#       9
# ---> 10 tree.fit(X_train, y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1245         """
#    1246
# -> 1247         super().fit(
#    1248             X, y,
#    1249             sample_weight=sample_weight,
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     154             check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     155             check_y_params = dict(ensure_2d=False, dtype=None)
# --> 156             X, y = self._validate_data(X, y,
#     157                                        validate_separately=(check_X_params,
# ...

# %%
clf = RandomizedSearchCV(DecisionTreeRegressor(), parameter_space, cv=4, 
                         scoring="neg_mean_absolute_error", n_iter=100)

# %%
from sklearn.tree import DecisionTreeRegressor

parameter_space = \
    {
        "criterion": ["mse", "friedman_mse", "mae"],
        "min_samples_split": [5, 18, 29, 50],
        "min_samples_leaf": [3, 7, 15, 25],
        "max_features": [20, 50, 150, 200, X_train.shape[1]],
    }

clf = GridSearchCV(DecisionTreeRegressor(random_state=3), parameter_space, 
                   cv=3, scoring="neg_mean_absolute_error", n_jobs=4)

clf.fit(X_train, y_train)
print("Best parameters:")
print(clf.best_params_)

# %%
dt_model = DecisionTreeRegressor(**clf.best_params_)

# %%
dt_model.fit(X_train, y_train);

# %% [markdown]
# #### to print the decision tree mean average score

# %%
y_pred = dt_model.predict(X_test)
dt_mae = mean_absolute_error(y_test, y_pred)
print("Decision Tree MAE =", dt_mae)
